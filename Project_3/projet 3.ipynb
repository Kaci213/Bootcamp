# %%
import os
import pandas as pd
import numpy as np
import re

# %%
input_df = pd.read_csv("6 - Primary Education.xlsx - Primary.csv")

# %%
input_df.columns
# Out:
# Index(['ISO3', 'Countries and areas', 'Region', 'Sub-region', 'Income Group',
#        'Total', 'Residence Rural', 'Residence Urban',
#        'Wealth quintile Poorest', 'Wealth quintile Richest', 'Data source',
#        'Time period'],
#       dtype='object')

# %%
input_df
# Out:
#    ISO3 Countries and areas Region Sub-region              Income Group  \
# 0   AGO              Angola    SSA        ESA  Lower middle income (LM)
# 1   ARG           Argentina    LAC        LAC  Upper middle income (UM)
# 2   ARM             Armenia    ECA       EECA  Upper middle income (UM)
# 3   BGD          Bangladesh     SA         SA  Lower middle income (LM)
# 4   BRB            Barbados    LAC        LAC           High income (H)
# ..  ...                 ...    ...        ...                       ...
# 82  URY             Uruguay    LAC        LAC           High income (H)
# 83  UZB          Uzbekistan    ECA       EECA  Lower middle income (LM)
# 84  VNM            Viet Nam    EAP        EAP                       NaN
# 85  ZMB              Zambia    SSA        ESA  Lower middle income (LM)
# 86  ZWE            Zimbabwe    SSA        ESA  Lower middle income (LM)
#
#     Total  Residence Rural  Residence Urban  Wealth quintile Poorest  \
# 0    0.15             0.02             0.22                     0.00
# 1    0.39              NaN              NaN                      NaN
# 2    0.81             0.69             0.89                     0.46
# 3    0.34             0.30             0.49                     0.07
# 4    0.63             0.54             0.68                     0.09
# ..    ...              ...              ...                      ...
# 82   0.63             0.53             0.64                     0.37
# 83   0.19             0.16             0.26                     0.00
# 84   0.58              NaN             0.58                      NaN
# 85   0.06             0.02             0.12                     0.00
# 86   0.25             0.16             0.48                     0.04
#
#     Wealth quintile Richest  \
# 0                      0.61
# 1                       NaN
# 2                      0.99
# 3                      0.75
# 4                      0.97
# ..                      ...
# 82                      NaN
# 83                     0.69
# 84                      NaN
# 85                     0.28
# 86                     0.60
#
#                                           Data source Time period
# 0                       Demographic and Health Survey     2015-16
# 1                   Multiple Indicator Cluster Survey     2011-12
# 2                       Demographic and Health Survey     2015-16
# 3                   Multiple Indicator Cluster Survey        2019
# 4                   Multiple Indicator Cluster Survey        2012
# ..                                                ...         ...
# 82                  Multiple Indicator Cluster Survey     2012-99
# 83                       UNICEF Nutrition Survey 2017        2017
# 84  STEP Skills Measurement Household Survey 2012 ...        2012
# 85                      Demographic and Health Survey     2018-19
# 86                  Multiple Indicator Cluster Survey     2018-19
#
# [87 rows x 12 columns]

# %% [markdown]
# # Cleaning column names

# %%
input_df.columns = [col.replace(' ', '_') for col in input_df.columns]
input_df.columns = [col.replace('-', '_') for col in input_df.columns]

# %%
input_df.columns
# Out:
# Index(['ISO3', 'Countries_and_areas', 'Region', 'Sub_region', 'Income_Group',
#        'Total', 'Residence_Rural', 'Residence_Urban',
#        'Wealth_quintile_Poorest', 'Wealth_quintile_Richest', 'Data_source',
#        'Time_period'],
#       dtype='object')

# %% [markdown]
# ### Looking for data type inconsistencies

# %%
for column in input_df.columns:
    if input_df[input_df[column].notnull()][column].apply(type).value_counts().shape[0] > 1:
        print(column, "has multiple data type")
    else:
        print("the data is consistant")
# Out:
# the data is consistant
# the data is consistant
# the data is consistant
# the data is consistant
# the data is consistant
# the data is consistant
# the data is consistant
# the data is consistant
# the data is consistant
# the data is consistant
# the data is consistant
# the data is consistant

# %% [markdown]
# # Inspection for cleaning

# %%
input_df.head()
# Out:
#   ISO3 Countries_and_areas Region Sub_region              Income_Group  Total  \
# 0  AGO              Angola    SSA        ESA  Lower middle income (LM)   0.15
# 1  ARG           Argentina    LAC        LAC  Upper middle income (UM)   0.39
# 2  ARM             Armenia    ECA       EECA  Upper middle income (UM)   0.81
# 3  BGD          Bangladesh     SA         SA  Lower middle income (LM)   0.34
# 4  BRB            Barbados    LAC        LAC           High income (H)   0.63
#
#    Residence_Rural  Residence_Urban  Wealth_quintile_Poorest  \
# 0             0.02             0.22                     0.00
# 1              NaN              NaN                      NaN
# 2             0.69             0.89                     0.46
# 3             0.30             0.49                     0.07
# 4             0.54             0.68                     0.09
#
#    Wealth_quintile_Richest                        Data_source Time_period
# 0                     0.61      Demographic and Health Survey     2015-16
# 1                      NaN  Multiple Indicator Cluster Survey     2011-12
# 2                     0.99      Demographic and Health Survey     2015-16
# 3                     0.75  Multiple Indicator Cluster Survey        2019
# 4                     0.97  Multiple Indicator Cluster Survey        2012

# %% [markdown]
# ### Clean the date format
# - keeping a single format
# - detecting the rows where the year does not make sense (year superior than 2023) to replace them

# %%
input_df.dtypes
# Out:
# ISO3                        object
# Countries_and_areas         object
# Region                      object
# Sub_region                  object
# Income_Group                object
# Total                      float64
# Residence_Rural            float64
# Residence_Urban            float64
# Wealth_quintile_Poorest    float64
# Wealth_quintile_Richest    float64
# Data_source                 object
# Time_period                 object
# dtype: object

# %%
input_df['Time_period'] = input_df['Time_period'].astype(str)

# %%
input_df['Time_period'] = input_df['Time_period'].apply(lambda str: str.split('-')[0] if '-' in str else str)

# %%
import datetime
current_year = datetime.date.today().year
input_df['Time_period'] = input_df['Time_period'].apply(lambda time: np.nan if int(time) > current_year else time)

# %%
input_df.sort_values('Time_period')
# Out:
#    ISO3    Countries_and_areas Region Sub_region              Income_Group  \
# 49  MAR                Morocco   MENA       MENA  Lower middle income (LM)
# 66  SSD            South Sudan    SSA        ESA            Low income (L)
# 10  BFA           Burkina Faso    SSA        WCA            Low income (L)
# 1   ARG              Argentina    LAC        LAC  Upper middle income (UM)
# 75  TTO    Trinidad and Tobago    LAC        LAC           High income (H)
# ..  ...                    ...    ...        ...                       ...
# 32  IDN              Indonesia    EAP        EAP  Lower middle income (LM)
# 60  STP  Sao Tome and Principe    SSA        WCA  Lower middle income (LM)
# 57  PER                   Peru    LAC        LAC  Upper middle income (UM)
# 51  NPL                  Nepal     SA         SA            Low income (L)
# 71  THA               Thailand    EAP        EAP  Upper middle income (UM)
#
#     Total  Residence_Rural  Residence_Urban  Wealth_quintile_Poorest  \
# 49   0.16             0.11             0.20                      NaN
# 66   0.00             0.00             0.01                     0.00
# 10   0.01             0.01             0.03                     0.01
# 1    0.39              NaN              NaN                      NaN
# 75   0.42             0.32             0.51                     0.02
# ..    ...              ...              ...                      ...
# 32   0.17             0.09             0.24                     0.05
# 60   0.44             0.37             0.47                     0.18
# 57   0.25             0.01             0.33                      NaN
# 51   0.46             0.31             0.54                     0.15
# 71   0.68             0.65             0.75                     0.42
#
#     Wealth_quintile_Richest                              Data_source  \
# 49                      NaN  Morocco Household and Youth Survey 2010
# 66                     0.02        Multiple Indicator Cluster Survey
# 10                     0.04            Demographic and Health Survey
# 1                       NaN        Multiple Indicator Cluster Survey
# 75                     0.97        Multiple Indicator Cluster Survey
# ..                      ...                                      ...
# 32                     0.44                                  SUSENAS
# 60                     0.75        Multiple Indicator Cluster Survey
# 57                      NaN                                    ENDES
# 51                     0.85        Multiple Indicator Cluster Survey
# 71                     0.95        Multiple Indicator Cluster Survey
#
#    Time_period
# 49        2010
# 66        2010
# 10        2010
# 1         2011
# 75        2011
# ..         ...
# 32        2019
# 60        2019
# 57        2019
# 51         NaN
# 71         NaN
#
# [87 rows x 12 columns]

# %% [markdown]
# ### Looking for missing values

# %%
input_df.isna().sum()
# Out:
# ISO3                        0
# Countries_and_areas         0
# Region                      1
# Sub_region                  5
# Income_Group                6
# Total                       5
# Residence_Rural            15
# Residence_Urban            13
# Wealth_quintile_Poorest    22
# Wealth_quintile_Richest    25
# Data_source                 2
# Time_period                 2
# dtype: int64

# %%
#shows all the rows where there is a missing value 
input_df[input_df.isnull().any(axis=1)]
# Out:
#    ISO3               Countries_and_areas Region Sub_region  \
# 1   ARG                         Argentina    LAC        LAC
# 6   BOL  Bolivia (Plurinational State of)    LAC        LAC
# 15  CHN                             China    EAP        EAP
# 23  ECU                           Ecuador    LAC        LAC
# 24  EGY                             Egypt   MENA       MENA
# 34  ITA                             Italy    ECA         WE
# 37  KEN                             Kenya    SSA        ESA
# 46  MEX                            Mexico    LAC        LAC
# 48  MNE                        Montenegro    ECA       EECA
# 49  MAR                           Morocco   MENA       MENA
# 51  NPL                             Nepal     SA         SA
# 52  NIC                         Nicaragua    LAC        LAC
# 53  NER                             Niger    SSA        WCA
# 54  NGA                           Nigeria    SSA        WCA
# 57  PER                              Peru    LAC        LAC
# 58  RUS                Russian Federation    ECA       EECA
# 59  LCA                       Saint Lucia    LAC        LAC
# 64  SOM                           Somalia    SSA        ESA
# 65  ZAF                      South Africa    SSA        ESA
# 70  TJK                        Tajikistan    NaN       EECA
# 71  THA                          Thailand    EAP        EAP
# 76  TUN                           Tunisia   MENA        NaN
# 77  TUR                            Turkey    ECA        NaN
# 78  TKM                   Turkmenistannnn    ECA        NaN
# 79  UGA                            Uganda    SSA        NaN
# 80  UKR                           Ukraine    ECA        NaN
# 81  GBR                    United Kingdom    ECA         WE
# 82  URY                           Uruguay    LAC        LAC
# 84  VNM                          Viet Nam    EAP        EAP
#
#                 Income_Group  Total  Residence_Rural  Residence_Urban  \
# 1   Upper middle income (UM)   0.39              NaN              NaN
# 6   Lower middle income (LM)   0.11             0.04             0.15
# 15  Upper middle income (UM)   0.62             0.53             0.91
# 23  Upper middle income (UM)   0.40             0.19             0.50
# 24  Lower middle income (LM)   0.16             0.09             0.27
# 34           High income (H)   0.63              NaN              NaN
# 37  Lower middle income (LM)   0.30              NaN             0.22
# 46  Upper middle income (UM)   0.37             0.10             0.47
# 48  Upper middle income (UM)   0.80             0.71             0.84
# 49  Lower middle income (LM)   0.16             0.11             0.20
# 51            Low income (L)   0.46             0.31             0.54
# 52  Lower middle income (LM)   0.04              NaN              NaN
# 53            Low income (L)   0.02              NaN              NaN
# 54  Lower middle income (LM)   0.03              NaN              NaN
# 57  Upper middle income (UM)   0.25             0.01             0.33
# 58  Upper middle income (UM)   0.88             0.82             0.90
# 59  Upper middle income (UM)   0.44             0.44             0.47
# 64            Low income (L)   0.12              NaN              NaN
# 65  Upper middle income (UM)   0.18              NaN              NaN
# 70            Low income (L)   0.23             0.19             0.37
# 71  Upper middle income (UM)   0.68             0.65             0.75
# 76                       NaN    NaN              NaN              NaN
# 77                       NaN    NaN              NaN              NaN
# 78                       NaN    NaN              NaN              NaN
# 79                       NaN    NaN              NaN              NaN
# 80                       NaN    NaN              NaN              NaN
# 81           High income (H)   0.99              NaN              NaN
# 82           High income (H)   0.63             0.53             0.64
# 84                       NaN   0.58              NaN             0.58
#
#     Wealth_quintile_Poorest  Wealth_quintile_Richest  \
# 1                       NaN                      NaN
# 6                       NaN                      NaN
# 15                      NaN                      NaN
# 23                      NaN                      NaN
# 24                      NaN                      NaN
# 34                      NaN                      NaN
# 37                      NaN                      NaN
# 46                      NaN                      NaN
# 48                     0.43                     1.00
# 49                      NaN                      NaN
# 51                     0.15                     0.85
# 52                      NaN                      NaN
# 53                      NaN                      NaN
# 54                      NaN                      NaN
# 57                      NaN                      NaN
# 58                     0.88                      NaN
# 59                     0.12                      NaN
# 64                      NaN                      NaN
# 65                      NaN                      NaN
# 70                     0.05                     0.44
# 71                     0.42                     0.95
# 76                      NaN                      NaN
# 77                      NaN                      NaN
# 78                      NaN                      NaN
# 79                      NaN                      NaN
# 80                      NaN                      NaN
# 81                      NaN                      NaN
# 82                     0.37                      NaN
# 84                      NaN                      NaN
#
#                                           Data_source Time_period
# 1                   Multiple Indicator Cluster Survey        2011
# 6                                                EDSA        2016
# 15                                        CHARLS 2018        2018
# 23                                            ENSANUT        2018
# 24  2015 Household Income, Expenditure and Consump...        2015
# 34  Multiscopo sulle famiglie: aspetti della vita ...        2018
# 37  STEP Skills Measurement Household Survey 2013 ...        2013
# 46                                            ENSANUT        2018
# 48                                                NaN        2018
# 49            Morocco Household and Youth Survey 2010        2010
# 51                  Multiple Indicator Cluster Survey         NaN
# 52  Nicaragua National Demographic and Health Surv...        2011
# 53  National Survey on Household Living Conditions...        2014
# 54  General Household Survey, Panel 2018-2019, Wave 4        2018
# 57                                              ENDES        2019
# 58        Russia Longitudinal Monitoring Survey, 2018        2018
# 59                  Multiple Indicator Cluster Survey        2012
# 64                      Somalia High Frequency Survey        2017
# 65      South Africa Living Conditions Survey 2014-15        2014
# 70                      Demographic and Health Survey        2017
# 71                  Multiple Indicator Cluster Survey         NaN
# 76                  Multiple Indicator Cluster Survey        2018
# 77                                                NaN        2013
# 78                  Multiple Indicator Cluster Survey        2019
# 79                                               LSMS        2015
# 80  STEP Skills Measurement Household Survey 2013 ...        2013
# 81  UK Data Archive Information for the Study 8298...        2016
# 82                  Multiple Indicator Cluster Survey        2012
# 84  STEP Skills Measurement Household Survey 2012 ...        2012

# %% [markdown]
# ### The year for Thailand and Nepal do not make sense, but since all the values are filled, we have decided not to drop them, and fill the year according to the Region & Data Source

# %%
# input_df[input_df['Data_source']=='Multiple Indicator Cluster Survey']
input_df[input_df['Region']=='SA']
input_df[input_df['Region']=='EAP']

# %%
#For Thailand and Nepal, in the EAP and SA region,  for the source Multiple Indicator Cluster Survey, this is the most probable year
input_df.at[71,'Time_period']='2019'
input_df.at[51,'Time_period']='2019'

# %%
input_df[input_df.isnull().any(axis=1)]
# Out:
#    ISO3               Countries_and_areas Region Sub_region  \
# 1   ARG                         Argentina    LAC        LAC
# 6   BOL  Bolivia (Plurinational State of)    LAC        LAC
# 15  CHN                             China    EAP        EAP
# 23  ECU                           Ecuador    LAC        LAC
# 24  EGY                             Egypt   MENA       MENA
# 34  ITA                             Italy    ECA         WE
# 37  KEN                             Kenya    SSA        ESA
# 46  MEX                            Mexico    LAC        LAC
# 48  MNE                        Montenegro    ECA       EECA
# 49  MAR                           Morocco   MENA       MENA
# 52  NIC                         Nicaragua    LAC        LAC
# 53  NER                             Niger    SSA        WCA
# 54  NGA                           Nigeria    SSA        WCA
# 57  PER                              Peru    LAC        LAC
# 58  RUS                Russian Federation    ECA       EECA
# 59  LCA                       Saint Lucia    LAC        LAC
# 64  SOM                           Somalia    SSA        ESA
# 65  ZAF                      South Africa    SSA        ESA
# 70  TJK                        Tajikistan    NaN       EECA
# 76  TUN                           Tunisia   MENA        NaN
# 77  TUR                            Turkey    ECA        NaN
# 78  TKM                   Turkmenistannnn    ECA        NaN
# 79  UGA                            Uganda    SSA        NaN
# 80  UKR                           Ukraine    ECA        NaN
# 81  GBR                    United Kingdom    ECA         WE
# 82  URY                           Uruguay    LAC        LAC
# 84  VNM                          Viet Nam    EAP        EAP
#
#                 Income_Group  Total  Residence_Rural  Residence_Urban  \
# 1   Upper middle income (UM)   0.39              NaN              NaN
# 6   Lower middle income (LM)   0.11             0.04             0.15
# 15  Upper middle income (UM)   0.62             0.53             0.91
# 23  Upper middle income (UM)   0.40             0.19             0.50
# 24  Lower middle income (LM)   0.16             0.09             0.27
# 34           High income (H)   0.63              NaN              NaN
# 37  Lower middle income (LM)   0.30              NaN             0.22
# 46  Upper middle income (UM)   0.37             0.10             0.47
# 48  Upper middle income (UM)   0.80             0.71             0.84
# 49  Lower middle income (LM)   0.16             0.11             0.20
# 52  Lower middle income (LM)   0.04              NaN              NaN
# 53            Low income (L)   0.02              NaN              NaN
# 54  Lower middle income (LM)   0.03              NaN              NaN
# 57  Upper middle income (UM)   0.25             0.01             0.33
# 58  Upper middle income (UM)   0.88             0.82             0.90
# 59  Upper middle income (UM)   0.44             0.44             0.47
# 64            Low income (L)   0.12              NaN              NaN
# 65  Upper middle income (UM)   0.18              NaN              NaN
# 70            Low income (L)   0.23             0.19             0.37
# 76                       NaN    NaN              NaN              NaN
# 77                       NaN    NaN              NaN              NaN
# 78                       NaN    NaN              NaN              NaN
# 79                       NaN    NaN              NaN              NaN
# 80                       NaN    NaN              NaN              NaN
# 81           High income (H)   0.99              NaN              NaN
# 82           High income (H)   0.63             0.53             0.64
# 84                       NaN   0.58              NaN             0.58
#
#     Wealth_quintile_Poorest  Wealth_quintile_Richest  \
# 1                       NaN                      NaN
# 6                       NaN                      NaN
# 15                      NaN                      NaN
# 23                      NaN                      NaN
# 24                      NaN                      NaN
# 34                      NaN                      NaN
# 37                      NaN                      NaN
# 46                      NaN                      NaN
# 48                     0.43                     1.00
# 49                      NaN                      NaN
# 52                      NaN                      NaN
# 53                      NaN                      NaN
# 54                      NaN                      NaN
# 57                      NaN                      NaN
# 58                     0.88                      NaN
# 59                     0.12                      NaN
# 64                      NaN                      NaN
# 65                      NaN                      NaN
# 70                     0.05                     0.44
# 76                      NaN                      NaN
# 77                      NaN                      NaN
# 78                      NaN                      NaN
# 79                      NaN                      NaN
# 80                      NaN                      NaN
# 81                      NaN                      NaN
# 82                     0.37                      NaN
# 84                      NaN                      NaN
#
#                                           Data_source Time_period
# 1                   Multiple Indicator Cluster Survey        2011
# 6                                                EDSA        2016
# 15                                        CHARLS 2018        2018
# 23                                            ENSANUT        2018
# 24  2015 Household Income, Expenditure and Consump...        2015
# 34  Multiscopo sulle famiglie: aspetti della vita ...        2018
# 37  STEP Skills Measurement Household Survey 2013 ...        2013
# 46                                            ENSANUT        2018
# 48                                                NaN        2018
# 49            Morocco Household and Youth Survey 2010        2010
# 52  Nicaragua National Demographic and Health Surv...        2011
# 53  National Survey on Household Living Conditions...        2014
# 54  General Household Survey, Panel 2018-2019, Wave 4        2018
# 57                                              ENDES        2019
# 58        Russia Longitudinal Monitoring Survey, 2018        2018
# 59                  Multiple Indicator Cluster Survey        2012
# 64                      Somalia High Frequency Survey        2017
# 65      South Africa Living Conditions Survey 2014-15        2014
# 70                      Demographic and Health Survey        2017
# 76                  Multiple Indicator Cluster Survey        2018
# 77                                                NaN        2013
# 78                  Multiple Indicator Cluster Survey        2019
# 79                                               LSMS        2015
# 80  STEP Skills Measurement Household Survey 2013 ...        2013
# 81  UK Data Archive Information for the Study 8298...        2016
# 82                  Multiple Indicator Cluster Survey        2012
# 84  STEP Skills Measurement Household Survey 2012 ...        2012

# %% [markdown]
# ### Filling missing region values

# %%
#The region is missing for Tajikistan, it is quite easy to find it and replace it, so we will keep this row
input_df.at[70,'Region']='ECA'

# %%
#for the missing sub-regions, we will simply copy the region, as it is not a very important column
input_df['Sub_region'].fillna(input_df['Region'], inplace = True)

# %%
input_df[input_df.isnull().any(axis=1)]
# Out:
#    ISO3               Countries_and_areas Region Sub_region  \
# 1   ARG                         Argentina    LAC        LAC
# 6   BOL  Bolivia (Plurinational State of)    LAC        LAC
# 15  CHN                             China    EAP        EAP
# 23  ECU                           Ecuador    LAC        LAC
# 24  EGY                             Egypt   MENA       MENA
# 34  ITA                             Italy    ECA         WE
# 37  KEN                             Kenya    SSA        ESA
# 46  MEX                            Mexico    LAC        LAC
# 48  MNE                        Montenegro    ECA       EECA
# 49  MAR                           Morocco   MENA       MENA
# 52  NIC                         Nicaragua    LAC        LAC
# 53  NER                             Niger    SSA        WCA
# 54  NGA                           Nigeria    SSA        WCA
# 57  PER                              Peru    LAC        LAC
# 58  RUS                Russian Federation    ECA       EECA
# 59  LCA                       Saint Lucia    LAC        LAC
# 64  SOM                           Somalia    SSA        ESA
# 65  ZAF                      South Africa    SSA        ESA
# 76  TUN                           Tunisia   MENA       MENA
# 77  TUR                            Turkey    ECA        ECA
# 78  TKM                   Turkmenistannnn    ECA        ECA
# 79  UGA                            Uganda    SSA        SSA
# 80  UKR                           Ukraine    ECA        ECA
# 81  GBR                    United Kingdom    ECA         WE
# 82  URY                           Uruguay    LAC        LAC
# 84  VNM                          Viet Nam    EAP        EAP
#
#                 Income_Group  Total  Residence_Rural  Residence_Urban  \
# 1   Upper middle income (UM)   0.39              NaN              NaN
# 6   Lower middle income (LM)   0.11             0.04             0.15
# 15  Upper middle income (UM)   0.62             0.53             0.91
# 23  Upper middle income (UM)   0.40             0.19             0.50
# 24  Lower middle income (LM)   0.16             0.09             0.27
# 34           High income (H)   0.63              NaN              NaN
# 37  Lower middle income (LM)   0.30              NaN             0.22
# 46  Upper middle income (UM)   0.37             0.10             0.47
# 48  Upper middle income (UM)   0.80             0.71             0.84
# 49  Lower middle income (LM)   0.16             0.11             0.20
# 52  Lower middle income (LM)   0.04              NaN              NaN
# 53            Low income (L)   0.02              NaN              NaN
# 54  Lower middle income (LM)   0.03              NaN              NaN
# 57  Upper middle income (UM)   0.25             0.01             0.33
# 58  Upper middle income (UM)   0.88             0.82             0.90
# 59  Upper middle income (UM)   0.44             0.44             0.47
# 64            Low income (L)   0.12              NaN              NaN
# 65  Upper middle income (UM)   0.18              NaN              NaN
# 76                       NaN    NaN              NaN              NaN
# 77                       NaN    NaN              NaN              NaN
# 78                       NaN    NaN              NaN              NaN
# 79                       NaN    NaN              NaN              NaN
# 80                       NaN    NaN              NaN              NaN
# 81           High income (H)   0.99              NaN              NaN
# 82           High income (H)   0.63             0.53             0.64
# 84                       NaN   0.58              NaN             0.58
#
#     Wealth_quintile_Poorest  Wealth_quintile_Richest  \
# 1                       NaN                      NaN
# 6                       NaN                      NaN
# 15                      NaN                      NaN
# 23                      NaN                      NaN
# 24                      NaN                      NaN
# 34                      NaN                      NaN
# 37                      NaN                      NaN
# 46                      NaN                      NaN
# 48                     0.43                      1.0
# 49                      NaN                      NaN
# 52                      NaN                      NaN
# 53                      NaN                      NaN
# 54                      NaN                      NaN
# 57                      NaN                      NaN
# 58                     0.88                      NaN
# 59                     0.12                      NaN
# 64                      NaN                      NaN
# 65                      NaN                      NaN
# 76                      NaN                      NaN
# 77                      NaN                      NaN
# 78                      NaN                      NaN
# 79                      NaN                      NaN
# 80                      NaN                      NaN
# 81                      NaN                      NaN
# 82                     0.37                      NaN
# 84                      NaN                      NaN
#
#                                           Data_source Time_period
# 1                   Multiple Indicator Cluster Survey        2011
# 6                                                EDSA        2016
# 15                                        CHARLS 2018        2018
# 23                                            ENSANUT        2018
# 24  2015 Household Income, Expenditure and Consump...        2015
# 34  Multiscopo sulle famiglie: aspetti della vita ...        2018
# 37  STEP Skills Measurement Household Survey 2013 ...        2013
# 46                                            ENSANUT        2018
# 48                                                NaN        2018
# 49            Morocco Household and Youth Survey 2010        2010
# 52  Nicaragua National Demographic and Health Surv...        2011
# 53  National Survey on Household Living Conditions...        2014
# 54  General Household Survey, Panel 2018-2019, Wave 4        2018
# 57                                              ENDES        2019
# 58        Russia Longitudinal Monitoring Survey, 2018        2018
# 59                  Multiple Indicator Cluster Survey        2012
# 64                      Somalia High Frequency Survey        2017
# 65      South Africa Living Conditions Survey 2014-15        2014
# 76                  Multiple Indicator Cluster Survey        2018
# 77                                                NaN        2013
# 78                  Multiple Indicator Cluster Survey        2019
# 79                                               LSMS        2015
# 80  STEP Skills Measurement Household Survey 2013 ...        2013
# 81  UK Data Archive Information for the Study 8298...        2016
# 82                  Multiple Indicator Cluster Survey        2012
# 84  STEP Skills Measurement Household Survey 2012 ...        2012

# %% [markdown]
# ### Filling income groups
# There is only one row that is worth filling (Vietnam), as all the others have no value. Given its total, we can considere it as an Upper middle income (UM)
# as China is considered Upper middle income (UM) with 0.62

# %%
input_df.at[84,'Income_Group']='Upper middle income (UM)'

# %% [markdown]
# ### Dropping columns that have more than 15% of missing values
# 15% of 88 rows = 13

# %%
null_cols = input_df.isna().sum()
null_cols[null_cols > 12]
# Out:
# Residence_Rural            15
# Residence_Urban            13
# Wealth_quintile_Poorest    22
# Wealth_quintile_Richest    25
# dtype: int64

# %%
drop_cols = list(null_cols[null_cols > 12].index)
input_df = input_df.drop(drop_cols, axis=1)

# %%
input_df
# Out:
#    ISO3 Countries_and_areas Region Sub_region              Income_Group  \
# 0   AGO              Angola    SSA        ESA  Lower middle income (LM)
# 1   ARG           Argentina    LAC        LAC  Upper middle income (UM)
# 2   ARM             Armenia    ECA       EECA  Upper middle income (UM)
# 3   BGD          Bangladesh     SA         SA  Lower middle income (LM)
# 4   BRB            Barbados    LAC        LAC           High income (H)
# ..  ...                 ...    ...        ...                       ...
# 82  URY             Uruguay    LAC        LAC           High income (H)
# 83  UZB          Uzbekistan    ECA       EECA  Lower middle income (LM)
# 84  VNM            Viet Nam    EAP        EAP  Upper middle income (UM)
# 85  ZMB              Zambia    SSA        ESA  Lower middle income (LM)
# 86  ZWE            Zimbabwe    SSA        ESA  Lower middle income (LM)
#
#     Total                                        Data_source Time_period
# 0    0.15                      Demographic and Health Survey        2015
# 1    0.39                  Multiple Indicator Cluster Survey        2011
# 2    0.81                      Demographic and Health Survey        2015
# 3    0.34                  Multiple Indicator Cluster Survey        2019
# 4    0.63                  Multiple Indicator Cluster Survey        2012
# ..    ...                                                ...         ...
# 82   0.63                  Multiple Indicator Cluster Survey        2012
# 83   0.19                       UNICEF Nutrition Survey 2017        2017
# 84   0.58  STEP Skills Measurement Household Survey 2012 ...        2012
# 85   0.06                      Demographic and Health Survey        2018
# 86   0.25                  Multiple Indicator Cluster Survey        2018
#
# [87 rows x 8 columns]

# %% [markdown]
# # Last cleaning touches

# %%
input_df.at[48,'Data_source']='Unknown'

# %%
input_df["Sub_region"] = input_df["Sub_region"].apply(lambda x : x  if x != "WCAAA" else "WCA")

# %% [markdown]
# ### Dropping the remaining rows that have missing values in the Total column

# %%
#drop the last rows that contain null values
# print(input_df.isna().any(axis = 1).value_counts())

# input_df = input_df.dropna(how = "any")
# print(input_df.shape)

input_df[input_df.isnull().any(axis=1)]
# Out:
#    ISO3 Countries_and_areas Region Sub_region Income_Group  Total  \
# 76  TUN             Tunisia   MENA       MENA          NaN    NaN
# 77  TUR              Turkey    ECA        ECA          NaN    NaN
# 78  TKM     Turkmenistannnn    ECA        ECA          NaN    NaN
# 79  UGA              Uganda    SSA        SSA          NaN    NaN
# 80  UKR             Ukraine    ECA        ECA          NaN    NaN
#
#                                           Data_source Time_period
# 76                  Multiple Indicator Cluster Survey        2018
# 77                                                NaN        2013
# 78                  Multiple Indicator Cluster Survey        2019
# 79                                               LSMS        2015
# 80  STEP Skills Measurement Household Survey 2013 ...        2013

# %%
input_df = input_df.dropna(how = "any")
input_df[input_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ISO3, Countries_and_areas, Region, Sub_region, Income_Group, Total, Data_source, Time_period]
# Index: []

# %% [markdown]
# ### Looking for duplicates

# %%
input_df[input_df.duplicated(keep = False)]
# Out:
# Empty DataFrame
# Columns: [ISO3, Countries_and_areas, Region, Sub_region, Income_Group, Total, Data_source, Time_period]
# Index: []

# %%
input_df[input_df.duplicated( ['ISO3'], keep = False)]
# no duplicates
# Out:
# Empty DataFrame
# Columns: [ISO3, Countries_and_areas, Region, Sub_region, Income_Group, Total, Data_source, Time_period]
# Index: []

# %% [markdown]
# ### Looking for outliers

# %%
stats = input_df.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#        count      mean       std  min     25%   50%     75%   max    IQR
# Total   82.0  0.911098  5.160959  0.0  0.0625  0.26  0.6275  47.0  0.565

# %%
outliers = pd.DataFrame(columns=input_df.columns)
outliers
for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = input_df[(input_df[col] < lower) |
                   (input_df[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)
outliers
# Out:
# C:\Users\kaci\AppData\Local\Temp\ipykernel_10000\1369975024.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
#    ISO3 Countries_and_areas Region Sub_region              Income_Group  \
# 39  KGZ          Kyrgyzstan    ECA       EECA  Lower middle income (LM)
#
#     Total                        Data_source Time_period Outlier
# 39   47.0  Multiple Indicator Cluster Survey        2018   Total

# %% [markdown]
# ### Remedy the outlier
# instead of deleting the row, we realized that the outlier were just not in the same unit as the other values, so we devided its value by 100

# %%
input_df.at[39,'Total']=0.47

# %% [markdown]
# ### Output data to csv

# %%
input_df.to_csv("cleaned_data.csv", index = False)

# %%
#"SELECT Region, AVERAGE(Total), AVERAGE(Residence_Rural), AVERAGE(Residence_Urban), AVERAGE(Wealth_quintile_Poorest), AVERAGE(Wealth_quintile_Richest) FROM Countries GROUP BY Region"
#"SELECT Sub-region, AVERAGE(Total), AVERAGE(Residence_Rural), AVERAGE(Residence_Urban), AVERAGE(Wealth_quintile_Poorest), AVERAGE(Wealth_quintile_Richest) FROM Countries GROUP BY Sub-region"

# %% [markdown]
# ### Optional, push automatically to SQL

# %%
#import pymysql
#from sqlalchemy import create_engine
#from creds import password
#engine = create_engine(f'mysql+pymysql://root:{password}]@localhost:3306/Countries')
#df_modified.to_sql('Countries', engine, if_exists='replace', index=False)
