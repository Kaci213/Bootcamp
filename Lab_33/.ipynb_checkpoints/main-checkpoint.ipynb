# %%
import pandas as pd

# %%
#Part 1: Upload the data

# %%
df = pd.read_csv('example_data_cleaning.xlsx - Sheet1.csv')

# %%
#Goal is to keep as much data as we can

# %%
df.head()
# Out:
#    TransactionID  ClientID  BirthYear   Amount Profession  Department  Risk
# 0              4     34985     1923.0     5670    manager          78   Low
# 1             16     34997     1923.0  2399090  developer          78  High
# 2             25     35006     1923.0    33050         HR          78  High
# 3             12     34993     1939.0    23430  professor          78   Low
# 4             21     35002     1939.0    16770    manager          78   Low

# %%
#Part 2: Analyze your data and create a plan for data preparation

# %%
df.describe()
# Out:
#        TransactionID      ClientID    BirthYear        Amount  Department
# count      30.000000     30.000000    28.000000  3.000000e+01        30.0
# mean       15.500000  34993.833333  1968.321429  1.010097e+05        78.0
# std         8.803408      8.132876    27.960360  4.342616e+05         0.0
# min         1.000000  34982.000000  1923.000000  1.230000e+03        78.0
# 25%         8.250000  34987.250000  1944.750000  1.233000e+04        78.0
# 50%        15.500000  34991.500000  1967.000000  1.899000e+04        78.0
# 75%        22.750000  34999.750000  1988.000000  2.953500e+04        78.0
# max        30.000000  35008.000000  2017.000000  2.399090e+06        78.0

# %%
#show rows with null values
df[df.isnull().any(axis=1)]
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 15             28     35008     1967.0   46370        NaN          78    High
# 16             29     35008     1976.0   50810        NaN          78  Medium
# 28             22     34987        NaN   18990     sailer          78    High
# 29              7     34988        NaN   12330    Manager          78  Medium

# %%
# Filling nas with mean for the BirthYear column. (didn't use it)
# data["BirthYear"].fillna(value=data.BirthYear.mean(), inplace=True)

# %%
df.shape
# Out:
# (30, 7)

# %%
df.drop_duplicates()
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession  Department  \
# 0               4     34985     1923.0     5670      manager          78
# 1              16     34997     1923.0  2399090    developer          78
# 2              25     35006     1923.0    33050           HR          78
# 3              12     34993     1939.0    23430    professor          78
# 4              21     35002     1939.0    16770      manager          78
# 5              11     34992     1944.0    21210   researcher          78
# 6              20     35001     1944.0    14550      student          78
# 7               3     34984     1945.0     3450      student          78
# 8              19     35000     1949.0    12330       barmen          78
# 9               9     34990     1953.0    16770      Manager          78
# 10              8     34989     1958.0    14550           HR          78
# 11              6     34987     1967.0    10110      Manager          78
# ...

# %%
df.value_counts('ClientID')
# Out:
# ClientID
# 35008    3
# 34987    3
# 34988    2
# 34989    2
# 34991    2
# 34997    1
# 35007    1
# 35006    1
# 35002    1
# 35001    1
# 35000    1
# 34999    1
# 34998    1
# 34982    1
# 34995    1
# 34994    1
# 34983    1
# 34992    1
# 34990    1
# 34986    1
# 34985    1
# 34984    1
# 34993    1
# dtype: int64

# %%
df.shape
# Out:
# (30, 7)

# %%
null_cols = df.isnull().sum()
null_cols[null_cols > 0]
# Out:
# BirthYear     2
# Profession    2
# dtype: int64

# %%
df.dtypes
# Out:
# TransactionID      int64
# ClientID           int64
# BirthYear        float64
# Amount             int64
# Profession        object
# Department         int64
# Risk              object
# dtype: object

# %%
##Cleaning Plan

#headings of the colums
start with this first

#cleaning after inspecting the df : 
- profession : need to clean to get small caps, change etudient to student
- missing values : birth year and profession (check the clientid to fill the values)
- need to change birth year type
- check for outlier
- check risk corellation

#coherence & data conistancy
driver that is born in 2017

#replacing missing values
- check for clientid 
- mode 

#low variance columns (can look at the number of unique values for categorical data columns)
can remove low variance column

#outliers
identifying them then see what we do with them
check and see if we need to drop rows
==>train the model better without outliers + sometimes value so extreme that it seems corrupt

#check duplicates
d

#cleansing plan
cleaning, missing values, outliers, duplicates, data consistency

# %%
df['Profession']= df['Profession'].str.lower()

# %%
df['Profession']= df['Profession'].str.replace('etudient', 'student')

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession  Department  \
# 0               4     34985     1923.0     5670      manager          78
# 1              16     34997     1923.0  2399090    developer          78
# 2              25     35006     1923.0    33050           hr          78
# 3              12     34993     1939.0    23430    professor          78
# 4              21     35002     1939.0    16770      manager          78
# 5              11     34992     1944.0    21210   researcher          78
# 6              20     35001     1944.0    14550      student          78
# 7               3     34984     1945.0     3450      student          78
# 8              19     35000     1949.0    12330       barmen          78
# 9               9     34990     1953.0    16770      manager          78
# 10              8     34989     1958.0    14550           hr          78
# 11              6     34987     1967.0    10110      manager          78
# ...

# %%
#Part 3: Data cleansing (missing values, outliers, duplicates, data consistently)

# %%
df.loc[28:29, :]
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 28             22     34987        NaN   18990     sailer          78    High
# 29              7     34988        NaN   12330    manager          78  Medium

# %%
# df[df['ClientID']==34987]
df[df['ClientID']==34988]
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 22             23     34988     1999.0   25650    manager          78     Low
# 29              7     34988        NaN   12330    manager          78  Medium

# %%
df.at[28,'BirthYear']=1967.0

# %%
df.at[29,'BirthYear']=1999.0

# %%
df
# Out:
#     TransactionID  ClientID  BirthYear   Amount   Profession  Department  \
# 0               4     34985     1923.0     5670      manager          78
# 1              16     34997     1923.0  2399090    developer          78
# 2              25     35006     1923.0    33050           hr          78
# 3              12     34993     1939.0    23430    professor          78
# 4              21     35002     1939.0    16770      manager          78
# 5              11     34992     1944.0    21210   researcher          78
# 6              20     35001     1944.0    14550      student          78
# 7               3     34984     1945.0     3450      student          78
# 8              19     35000     1949.0    12330       barmen          78
# 9               9     34990     1953.0    16770      manager          78
# 10              8     34989     1958.0    14550           hr          78
# 11              6     34987     1967.0    10110      manager          78
# ...

# %%
df['BirthYear'] = df['BirthYear'].astype('int64')
df['BirthYear'].dtype
# Out:
# dtype('int64')

# %%
df.loc[15:16, :]
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 15             28     35008       1967   46370        NaN          78    High
# 16             29     35008       1976   50810        NaN          78  Medium

# %%
df[df['ClientID']==35008]
#drop sailer ?
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 14             27     35008       1967   41930        bdm          78     Low
# 15             28     35008       1967   46370        NaN          78    High
# 16             29     35008       1976   50810        NaN          78  Medium

# %%
df.at[15,'Profession']='bdm'
df.at[16,'Profession']='bdm'

# %%
df[df['ClientID']==35008]
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 14             27     35008       1967   41930        bdm          78     Low
# 15             28     35008       1967   46370        bdm          78    High
# 16             29     35008       1976   50810        bdm          78  Medium

# %%
#this data doesn't make sense
df['BirthYear'].sort_values(ascending=False).head(3)
# Out:
# 27    2017
# 26    2015
# 25    2013
# Name: BirthYear, dtype: int64

# %%
df.loc[25:27,:]
# Out:
#     TransactionID  ClientID  BirthYear  Amount Profession  Department    Risk
# 25              1     34982       2013   12900    student          78     Low
# 26              2     34983       2015    1230     barmen          78    High
# 27             13     34994       2017   25650     driver          78  Medium

# %%
df['BirthYear'].mean
# Out:
# 1951

# %%
#replace weird BirthYear by the mean value
df.at[25,'BirthYear']=1951
df.at[26,'BirthYear']=1951
df.at[27,'BirthYear']=1951

# %%
import numpy as np
df_pivot = df.pivot_table(index = ['ClientID','Profession','TransactionID','BirthYear'], values = ['Amount'], aggfunc={'Amount': np.sum})
df_pivot
# Out:
#                                                Amount
# ClientID Profession  TransactionID BirthYear
# 34982    student     1             1951         12900
# 34983    barmen      2             1951          1230
# 34984    student     3             1945          3450
# 34985    manager     4             1923          5670
# 34986    hr          5             1978          7890
# 34987    manager     6             1967         10110
#                      15            1967         30090
#          sailer      22            1967         18990
# 34988    manager     7             1999         12330
#                      23            1999         25650
# 34989    hr          8             1958         14550
#                      24            1967         27870
# 34990    manager     9             1953         16770
# 34991    bdm         10            1988         18990
#                      30            1988         55250
# 34992    researcher  11            1944         21210
# ...

# %%
#the last client has 3 transactions, and in one of them he has a different birthyear so we change it
df.at[16,'BirthYear']=1967

# %%
#Outliers

stats = df.describe().transpose()
stats['IQR'] = stats['75%'] - stats['25%']
stats
# Out:
#                count           mean            std      min       25%  \
# TransactionID   30.0      15.500000       8.803408      1.0      8.25
# ClientID        30.0   34993.833333       8.132876  34982.0  34987.25
# BirthYear       30.0    1962.600000      23.019632   1923.0   1946.00
# Amount          30.0  101009.666667  434261.568869   1230.0  12330.00
# Department      30.0      78.000000       0.000000     78.0     78.00
#
#                    50%       75%        max      IQR
# TransactionID     15.5     22.75       30.0     14.5
# ClientID       34991.5  34999.75    35008.0     12.5
# BirthYear       1967.0   1978.00     1999.0     32.0
# Amount         18990.0  29535.00  2399090.0  17205.0
# Department        78.0     78.00       78.0      0.0

# %%
outliers = pd.DataFrame(columns=df.columns)
outliers
for col in stats.index:
    iqr = stats.at[col,'IQR']
    cutoff = iqr * 1.5
    lower = stats.at[col,'25%'] - cutoff
    upper = stats.at[col,'75%'] + cutoff
    results = df[(df[col] < lower) |
                   (df[col] > upper)].copy()
    results['Outlier'] = col
    outliers = outliers.append(results)
outliers
# Out:
# C:\Users\kaci\AppData\Local\Temp\ipykernel_14932\369362288.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# C:\Users\kaci\AppData\Local\Temp\ipykernel_14932\369362288.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# C:\Users\kaci\AppData\Local\Temp\ipykernel_14932\369362288.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# C:\Users\kaci\AppData\Local\Temp\ipykernel_14932\369362288.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   outliers = outliers.append(results)
# ...

# %%
#even though it is an outlier, I believe we should keep this row

# %%
#Part 4: Encode categorical data

# %%
get dummies for profession ?

# %%
categoricalencoder for risk

# %%
#Part 5: Upload the deliverables to GitHub
